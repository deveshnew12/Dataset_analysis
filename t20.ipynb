# %% [markdown]
# <a href="https://colab.research.google.com/github/deveshnew12/Dataset_analysis/blob/main/t20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crik=pd.read_csv('kaggle_data.csv')
crik
# Out:
#    Unnamed: 0       team_1  ...    Player_of_the_match       Winner
# 0     Match_1    Australia  ...         Josh_Hazlewood    Australia
# 1     Match_2      England  ...              Moeen_Ali      England
# 2     Match_3     Srilanka  ...       Charith_Asalanka     Srilanka
# 3     Match_4     Pakistan  ...           Shaheen_shah     Pakistan
# 4     Match_5  Afghanistan  ...       Mujeeb_ur_Rehman  Afghanistan
# 5     Match_6  SouthAfrica  ...          Anrich_Nortje  SouthAfrica
# 6     Match_7     Pakistan  ...             Haris_Rauf     Pakistan
# 7     Match_8      England  ...              Jason_Roy      England
# 8     Match_9      Namibia  ...      Ruben_Trumpelmann      Namibia
# 9    Match_10    Australia  ...             Adam_Zampa    Australia
# 10   Match_11      Windies  ...        Nicholas_Pooran      Windies
# 11   Match_12     Pakistan  ...               Asif_Ali     Pakistan
# 12   Match_13  SouthAfrica  ...         Tabraiz_Shamsi  SouthAfrica
# ...

# %%
plt.pie(crik['avg_temperature'], labels=crik["venue"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4257082d10>,
# ...
#  [Text(1.0947687415257237, 0.10715130693642187, 'Abu_Dhabi'),
#   Text(1.0500700774840563, 0.3276474208240131, 'Dubai'),
#   Text(0.9544115958080616, 0.5468989904791463, 'Sharjah'),
#   Text(0.8112064428791762, 0.7429294091845564, 'Dubai'),
#   Text(0.6314223904207708, 0.900725132809849, 'Sharjah'),
#   Text(0.4250796320150062, 1.014547833493319, 'Dubai'),
#   Text(0.2132834634921808, 1.0791247213370565, 'Sharjah'),
#   Text(0.0035773831362301218, 1.0999941828618445, 'Abu_Dhabi'),
#   Text(-0.2062600024794923, 1.0804891537526695, 'Abu_Dhabi'),
#   Text(-0.401875127944346, 1.023961123060693, 'Dubai'),
#   Text(-0.5867490424339561, 0.9304437442440224, 'Sharjah'),
#   Text(-0.7560215055683343, 0.7990190755659023, 'Dubai'),
#   Text(-0.8986668861848762, 0.6343483488390104, 'Sharjah'),
#   Text(-1.0060606449428142, 0.4447943105495494, 'Dubai'),
#   Text(-1.0732110751496469, 0.24128404045054294, 'Abu_Dhabi'),
# ...

# %%
plt.pie(crik['strike_rate'], labels=[])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f40ce27e590>,
# ...
#  [Text(1.0973520710797695, 0.07627864771311084, ''),
#   Text(1.0765282854996365, 0.2260240042986881, ''),
#   Text(1.0227319809852482, 0.40499295681528835, ''),
#   Text(0.9268666748479075, 0.592383462848503, ''),
#   Text(0.7921549331255904, 0.7632106930099917, ''),
#   Text(0.6171624310812011, 0.9105550689892083, ''),
#   Text(0.46363754272720037, 0.9975170319217029, ''),
#   Text(0.2978529425812854, 1.0589068063789513, ''),
#   Text(0.07933217300131812, 1.09713554601375, ''),
#   Text(-0.13850334417306137, 1.0912455377470638, ''),
#   Text(-0.3111968578423337, 1.055062327859856, ''),
#   Text(-0.44703088580521155, 1.005068846963335, ''),
#   Text(-0.5878633101302138, 0.929740140363289, ''),
#   Text(-0.7735434553912113, 0.7820681061272255, ''),
#   Text(-0.9277795347554348, 0.5909527349027069, ''),
#   Text(-1.015500270036824, 0.4227992449793845, ''),
#   Text(-1.0751651337578396, 0.23242189043092956, ''),
# ...

# %%
# plt.xlabele('best_bowler')
# plt.ylabele('most_individual_wickets')
# plt.title('wicket')
# plt.xlabele('best_bowler')
plt.plot(crik['best_bowler'],crik['most_individual_wickets'])
plt.show()

# %%
plt.plot
